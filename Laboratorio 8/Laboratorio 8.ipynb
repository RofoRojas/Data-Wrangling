# %%
import numpy as np
import pandas as pd
import statistics as st
from sklearn.impute import SimpleImputer

# %%
df_MD = pd.read_csv('data/titanic_MD.csv')
print('dataset shape:', df_MD.shape)
df_MD.head()
# Out:
# dataset shape: (183, 12)
#    PassengerId  Survived  Pclass  \
# 0            2         1       1
# 1            4         1       1
# 2            7         0       1
# 3           11         1       3
# 4           12         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...       ?  38.0    1.0
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 2                            McCarthy, Mr. Timothy J    male  54.0    0.0
# 3                    Sandstrom, Miss. Marguerite Rut  female   NaN    1.0
# 4                           Bonnell, Miss. Elizabeth  female  58.0    NaN
#
#    Parch    Ticket     Fare Cabin Embarked
# 0    0.0  PC 17599  71.2833   C85        C
# 1    0.0    113803  53.1000  C123        S
# 2    0.0     17463  51.8625   E46        S
# 3    NaN   PP 9549  16.7000    G6        S
# 4    0.0    113783  26.5500  C103        S

# %%
df_MD.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  158.000000  180.000000
# mean    455.366120    0.672131    1.191257   35.692532    0.461111
# std     247.052476    0.470725    0.515187   15.640858    0.646122
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   35.500000    0.000000
# 75%     676.000000    1.000000    1.000000   48.000000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  171.000000  175.000000
# mean     0.461988   78.959191
# std      0.753435   77.026328
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   56.929200
# 75%      1.000000   90.539600
# max      4.000000  512.329200

# %%
df_MD.isna().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            25
# SibSp           3
# Parch          12
# Ticket          0
# Fare            8
# Cabin           0
# Embarked       12
# dtype: int64

# %%
np.unique(df_MD['Sex'])
# Out:
# array(['?', 'female', 'male'], dtype=object)

# %% [markdown]
# Cambiar **"?"** a NAN

# %%
df_MD.replace(r'\?', np.nan, regex = True, inplace = True)

# %%
df_MD.isna().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex            51
# Age            25
# SibSp           3
# Parch          12
# Ticket          0
# Fare            8
# Cabin           0
# Embarked       12
# dtype: int64

# %% [markdown]
# Las columnas que estan completas son: <br />
# **PassengerId <br />
# Survived <br />
# Pclass <br />
# Name <br />
# Ticket y <br />
# Cabin**

# %% [markdown]
# Las columnas con Missing Values son: <br/>
# **Sex <br/>
# Age <br/>
# SibSp <br/>
# Parch <br/>
# Fare <br/>
# Embarked**

# %%
def Missing_Handler(data_frame, handler, *completas_var):
    """En esta funcion se pueden pasar columnas donde se transformaran los missing values de diferentes formas
    Siendo posibles:
    a.	Listwise deletion
    b.	Pairwise deletion
    c.	Imputación general (1 media, 2 moda y 3 mediana)
    d.	Imputación sectorizada
    e.	Modelo de regresión lineal
    f.	Outliers: Standard deviation approach
    g.	Outliers: Percentile approach
    """
    if handler == "a":
        data_final =df_MD.dropna()
        print("Using Listwise")
    elif handler == "b":
        data_final=df_MD.corr()
        print("Using Pairwise")
    elif handler == "c1":
        for col in df.columns:
        col_imp =SimpleImputer(missing_values=np.nan, strategy= 'mean')
        print("Usando Imputacion con media")
    
    else:
        print("a is greater than b")
    
    return(data_final)

# %%
real = pd.read_csv('data/titanic.csv')

# %%
np.unique(real['Embarked'])
# Out:
# array(['C', 'Q', 'S'], dtype=object)

# %%
data_final= df_MD
for col in df_MD.select_dtypes(include='float').columns:
    col_imp =SimpleImputer(missing_values=np.nan, strategy= 'mean')
    #data_final= SimpleImputer(missing_values=np.nan, strategy= 'mean')
    data_final[[col]]= col_imp.fit_transform(df_MD[[col]])

# %%
data_final= df_MD
col_imp =SimpleImputer(missing_values=np.nan, strategy= 'mean')
#data_final= SimpleImputer(missing_values=np.nan, strategy= 'mean')
data_final[['Age']]=col_imp.fit_transform(data_final[['Age']])

# %%
data_final
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              4         1       1
# 2              7         0       1
# 3             11         1       3
# 4             12         1       1
# 5             22         1       2
# 6             24         1       1
# 7             28         0       1
# 8             53         1       1
# 9             55         0       1
# 10            63         0       1
# 11            67         1       2
# 12            76         0       3
# 13            89         1       1
# 14            93         0       1
# 15            97         0       1
# 16            98         1       1
# 17           103         0       1
# 18           111         0       1
# 19           119         0       1
# 20           124         1       2
# 21           125         0       1
# 22           137         1       1
# 23           138         0       1
# 24           140         0       1
# ...

# %%
df_MD
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              4         1       1
# 2              7         0       1
# 3             11         1       3
# 4             12         1       1
# 5             22         1       2
# 6             24         1       1
# 7             28         0       1
# 8             53         1       1
# 9             55         0       1
# 10            63         0       1
# 11            67         1       2
# 12            76         0       3
# 13            89         1       1
# 14            93         0       1
# 15            97         0       1
# 16            98         1       1
# 17           103         0       1
# 18           111         0       1
# 19           119         0       1
# 20           124         1       2
# 21           125         0       1
# 22           137         1       1
# 23           138         0       1
# 24           140         0       1
# ...

# %%
cols = []
val = []
for col in df.select_dtypes(include='object').columns:
    cols.append(col)
    val.append(df[col].str.contains(r'\?').sum())
pd.DataFrame({
    'cols':cols,
    'val':val
})

# %%
Missing_Handler(df_MD, "b")
# Out:
# a and b are equal
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000  0.148495 -0.089136 -0.048190 -0.088806 -0.062083
# Survived        0.148495  1.000000 -0.034542 -0.257703  0.113987 -0.003365
# Pclass         -0.089136 -0.034542  1.000000 -0.297872 -0.102294  0.041969
# Age            -0.048190 -0.257703 -0.297872  1.000000 -0.087951 -0.279548
# SibSp          -0.088806  0.113987 -0.102294 -0.087951  1.000000  0.255152
# Parch          -0.062083 -0.003365  0.041969 -0.279548  0.255152  1.000000
# Fare            0.022261  0.119311 -0.304438 -0.130979  0.299061  0.381445
#
#                  Fare
# PassengerId  0.022261
# Survived     0.119311
# Pclass      -0.304438
# Age         -0.130979
# SibSp        0.299061
# Parch        0.381445
# Fare         1.000000
